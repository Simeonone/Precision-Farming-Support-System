# %%
import cv2
import numpy as np
import matplotlib.pyplot as  plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a2d66570c1a0> in <module>
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as  plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import matplotlib.pyplot as  plt

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2

# %%
clear

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('precisionag.jpg')
img
# Out:
# array([[[ 13, 150,  59],
#         [  0, 137,  49],
#         [  0, 136,  52],
#         ...,
#         [105, 134,  35],
#         [ 94,  93,   7],
#         [128, 114,  32]],
#
#        [[  0, 137,  57],
#         [  9, 157,  79],
#         [ 39, 195, 118],
#         ...,
#         [ 87, 124,  30],
#         [ 85,  89,   0],
#         [ 90,  77,   0]],
#
#        [[  9, 175, 116],
#         [ 28, 196, 137],
#         [ 40, 213, 153],
#         ...,
#         [ 47, 105,  16],
#         [ 94, 107,  15],
#         [ 95,  87,   0]],
#
#        ...,
#
#        [[177,  83,   0],
#         [180,  84,   1],
#         [185,  86,   4],
#         ...,
#         [ 79, 152, 136],
#         [ 44, 128, 110],
#         [  7,  96,  77]],
#
#        [[176,  77,   9],
#         [177,  77,   5],
#         [180,  79,   4],
#         ...,
#         [ 51, 143, 126],
#         [ 57, 156, 140],
#         [ 45, 149, 132]],
#
#        [[169,  68,   6],
#         [169,  67,   2],
#         [173,  71,   0],
#         ...,
#         [ 18, 120, 103],
#         [ 28, 135, 119],
#         [ 20, 132, 115]]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (720, 960, 3)

# %%
plt.imshow(img)

# %%
normal = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(normal)

# %%
plt.show()

# %%
def get_image(image,cmap=None):
    plt.imshow(image,cmap=cmap)
    plt.show()

# %%
get_image(normal)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
get_image(hsv)
